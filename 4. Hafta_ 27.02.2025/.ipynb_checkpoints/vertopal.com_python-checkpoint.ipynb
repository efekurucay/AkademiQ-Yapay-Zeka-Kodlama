# %% [markdown]
# # Soru 21: Not ortalamasını hesaplayıp geçip geçmediğini kontrol eder.
#
# notlar = \[int(input()) for \_ in range(3)\] print(“Geçti” if
# sum(notlar)/3 \> 50 else “Kaldı”)
#
# # Soru 22: VKİ’ye göre fazla kilolu olup olmadığını kontrol eder.
#
# boy, kilo = float(input()), float(input()) vki = kilo / boy \*\* 2
# print(“Fazla kilolu” if vki \> 25 else “Normal”)
#
# # Soru 23: Dört işlem menüsü sunar.
#
# a, b = int(input()), int(input()) islem = input(“İşlem seçiniz (+, -, *,
# /): ”) match islem: case ”+”: print(a + b) case ”-”: print(a - b) case
# ”*”: print(a \* b) case “/”: print(a / b)
#
# # Soru 24: Dört sayıdan en küçüğünü bulur.
#
# sayilar = \[int(input()) for \_ in range(4)\] print(min(sayilar))
#
# # Soru 25: Üç sayıyı küçükten büyüğe sıralar.
#
# sayilar = sorted(int(input()) for \_ in range(3)) print(sayilar)
#
# # Soru 26: While döngüsü ile 1-N arası toplamı bulur.
#
# N, toplam = int(input()), 0 while N: toplam += N N -= 1 print(toplam)
#
# # Soru 27: 1-5 arası sayıların çarpımını bulur.
#
# carpim = 1 for i in range(1, 6): carpim \*= i print(carpim)
#
# # Soru 28: 1-10 arası sayıların karelerinin toplamını bulur.
#
# print(sum(i\*\*2 for i in range(1, 11)))
#
# # Soru 29: 1-N arası sayıların küplerinin toplamını bulur.
#
# N = int(input()) print(sum(i\*\*3 for i in range(1, N+1)))
#
# # Soru 30: 1-100 arasında 3 ve 5’e bölünen sayıları sayar.
#
# print(len(\[i for i in range(1, 101) if i % 15 == 0\]))
#
# # Soru 31: Sayıdan harf notunu belirler.
#
# notu = int(input()) if notu \>= 90: print(“A”) elif notu \>= 80:
# print(“B”) elif notu \>= 70: print(“C”) elif notu \>= 60: print(“D”)
# else: print(“F”)
#
# # Soru 32: Üç sayının eşitliğini kontrol eder.
#
# a, b, c = int(input()), int(input()), int(input()) if a == b == c:
# print(“Tüm sayılar eşit”) elif a == b or b == c or a == c: print(“İki
# sayı eşit”) else: print(“Hiçbiri eşit değil”)
#
# # Soru 33: Artık yıl kontrolü yapar.
#
# yil = int(input()) print(“Artık yıl” if (yil % 4 == 0 and yil % 100 !=
# 0) or yil % 400 == 0 else “Değil”)
#
# # Soru 34: BMI kategorisi belirler.
#
# boy, kilo = float(input()), float(input()) bmi = kilo / boy \*\* 2 if
# bmi \< 18.5: print(“Zayıf”) elif bmi \< 25: print(“Normal”) elif bmi \<
# 30: print(“Fazla Kilolu”) else: print(“Obez”)
#
# # Soru 35: Üçgen türünü belirler.
#
# a, b, c = int(input()), int(input()), int(input()) if a+b\>c and a+c\>b
# and b+c\>a: if a == b == c: print(“Eşkenar”) elif a == b or b == c or a
# == c: print(“İkizkenar”) else: print(“Çeşitkenar”) else: print(“Üçgen
# değil”)
#
# # Soru 36: Yaşa göre bilet fiyatını belirler.
#
# yas = int(input()) if yas \<= 5: print(“Ücretsiz”) elif yas \<= 18:
# print(“10 TL”) elif yas \<= 64: print(“20 TL”) else: print(“15 TL”)
#
# # Soru 37: Hava durumu önerisi verir.
#
# durum, sicaklik = input(), int(input()) if durum == “güneşli” and
# sicaklik \>= 25: print(“Piknik yapabilirsiniz.”) elif durum ==
# “yağmurlu”: print(“Şemsiye almayı unutmayın.”) elif durum == “karlı” and
# sicaklik \< 0: print(“Kayak yapmaya gidebilirsiniz.”) else: print(“Evde
# kalabilirsiniz.”)
#
# # Soru 38: Pozitif, negatif veya sıfır kontrolü yapar (2. soru ile aynı).
#
# # Soru 39: İki sayı karşılaştırması yapar.
#
# a, b = int(input()), int(input()) if a \> b: print(“Birinci sayı büyük”)
# elif b \> a: print(“İkinci sayı büyük”) else: print(“Sayılar eşit”)
#
# # Soru 40: Üyelik durumuna göre indirim hesaplar.
#
# tutar, durum = float(input()), input() indirim = 0.1 if durum == “üye”
# else 0.05 print(“İndirimli tutar:”, tutar\*(1-indirim))
